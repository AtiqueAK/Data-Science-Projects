# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/bhp.csv")
df
# Out:
#                        location       size  ...  bhk  price_per_sqft
# 0      Electronic City Phase II      2 BHK  ...    2            3699
# 1              Chikka Tirupathi  4 Bedroom  ...    4            4615
# 2                   Uttarahalli      3 BHK  ...    3            4305
# 3            Lingadheeranahalli      3 BHK  ...    3            6245
# 4                      Kothanur      2 BHK  ...    2            4250
# ...                         ...        ...  ...  ...             ...
# 13195                Whitefield  5 Bedroom  ...    5            6689
# 13196                     other      4 BHK  ...    4           11111
# 13197     Raja Rajeshwari Nagar      2 BHK  ...    2            5258
# 13198           Padmanabhanagar      4 BHK  ...    4           10407
# 13199              Doddathoguru      1 BHK  ...    1            3090
#
# [13200 rows x 7 columns]

# %%
cars=pd.read_excel("/content/cars.xlsx")
cars
# Out:
#      symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0            3                 ?  alfa-romero  ...       21          27  13495
# 1            3                 ?  alfa-romero  ...       21          27  16500
# 2            1                 ?  alfa-romero  ...       19          26  16500
# 3            2               164         audi  ...       24          30  13950
# 4            2               164         audi  ...       18          22  17450
# ..         ...               ...          ...  ...      ...         ...    ...
# 200         -1                95        volvo  ...       23          28  16845
# 201         -1                95        volvo  ...       19          25  19045
# 202         -1                95        volvo  ...       18          23  21485
# 203         -1                95        volvo  ...       26          27  22470
# 204         -1                95        volvo  ...       19          25  22625
#
# [205 rows x 15 columns]

# %%
cars.head()
# Out:
#    symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0          3                 ?  alfa-romero  ...       21          27  13495
# 1          3                 ?  alfa-romero  ...       21          27  16500
# 2          1                 ?  alfa-romero  ...       19          26  16500
# 3          2               164         audi  ...       24          30  13950
# 4          2               164         audi  ...       18          22  17450
#
# [5 rows x 15 columns]

# %%
cars.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# body-style           0
# drive-wheels         0
# engine-location      0
# width                0
# height               0
# engine-type          0
# engine-size          0
# horsepower           0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# memory usage: 24.1+ KB

# %%
cars["normalized-losses"].value_counts()
# Out:
# ?      41
# 161    11
# 91      8
# 150     7
# 128     6
# 104     6
# 134     6
# 103     5
# 85      5
# 168     5
# 102     5
# 65      5
# 74      5
# 95      5
# 94      5
# 148     4
# 118     4
# 106     4
# 122     4
# 93      4
# 137     3
# 154     3
# 83      3
# 125     3
# 101     3
# 115     3
# 87      2
# 129     2
# 119     2
# 145     2
# 113     2
# 153     2
# 110     2
# 108     2
# 158     2
# 89      2
# 164     2
# 188     2
# 192     2
# 194     2
# 197     2
# 81      2
# 231     1
# 186     1
# 107     1
# 256     1
# 98      1
# 77      1
# 142     1
# 78      1
# 121     1
# 90      1
# Name: normalized-losses, dtype: int64

# %%
cars["normalized-losses"].replace("?",np.nan,inplace=True)

# %%
cars.head()
# Out:
#    symboling  normalized-losses         make  ... city-mpg highway-mpg  price
# 0          3                NaN  alfa-romero  ...       21          27  13495
# 1          3                NaN  alfa-romero  ...       21          27  16500
# 2          1                NaN  alfa-romero  ...       19          26  16500
# 3          2              164.0         audi  ...       24          30  13950
# 4          2              164.0         audi  ...       18          22  17450
#
# [5 rows x 15 columns]

# %%
cars["normalized-losses"].value_counts()
# Out:
# 161.0    11
# 91.0      8
# 150.0     7
# 104.0     6
# 128.0     6
# 134.0     6
# 102.0     5
# 85.0      5
# 103.0     5
# 168.0     5
# 74.0      5
# 95.0      5
# 94.0      5
# 65.0      5
# 122.0     4
# 148.0     4
# 118.0     4
# 93.0      4
# 106.0     4
# 115.0     3
# 125.0     3
# 83.0      3
# 101.0     3
# 137.0     3
# 154.0     3
# 188.0     2
# 81.0      2
# 192.0     2
# 158.0     2
# 145.0     2
# 113.0     2
# 110.0     2
# 153.0     2
# 129.0     2
# 194.0     2
# 197.0     2
# 87.0      2
# 89.0      2
# 119.0     2
# 164.0     2
# 108.0     2
# 231.0     1
# 107.0     1
# 78.0      1
# 256.0     1
# 98.0      1
# 121.0     1
# 77.0      1
# 142.0     1
# 90.0      1
# 186.0     1
# Name: normalized-losses, dtype: int64

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 24.1+ KB

# %%
cars["normalized-losses"].fillna(cars["normalized-losses"].mean(),inplace=True)

# %%
cars.head()
# Out:
#    symboling  normalized-losses         make  ... city-mpg highway-mpg  price
# 0          3              122.0  alfa-romero  ...       21          27  13495
# 1          3              122.0  alfa-romero  ...       21          27  16500
# 2          1              122.0  alfa-romero  ...       19          26  16500
# 3          2              164.0         audi  ...       24          30  13950
# 4          2              164.0         audi  ...       18          22  17450
#
# [5 rows x 15 columns]

# %%
cars["horsepower"].value_counts()
# Out:
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 88      6
# 114     6
# 62      6
# 101     6
# 160     6
# 102     5
# 97      5
# 76      5
# 82      5
# 84      5
# 145     5
# 123     4
# 111     4
# 86      4
# 92      4
# 73      3
# 207     3
# 182     3
# 85      3
# 90      3
# 152     3
# 121     3
# ?       2
# 176     2
# 184     2
# 162     2
# 156     2
# 155     2
# 56      2
# 52      2
# 100     2
# 161     2
# 94      2
# 112     2
# 288     1
# 262     1
# 135     1
# 140     1
# 142     1
# 143     1
# 120     1
# 115     1
# 154     1
# 60      1
# 58      1
# 200     1
# 134     1
# 175     1
# 78      1
# 72      1
# 64      1
# 55      1
# 48      1
# 106     1
# Name: horsepower, dtype: int64

# %%
cars["horsepower"].replace("?",np.nan,inplace=True)

# %%
cars["horsepower"].fillna(cars["horsepower"].mean(),inplace=True)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    float64
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 24.1+ KB

# %% [markdown]
# 2)
# using box plot

# %%
plt.figure(figsize=(7,8))
sns.boxplot(data=cars,x="price",y="make")
plt.grid()
plt.show()

# %%
cars[(cars["make"]=="toyota")&(cars["price"]>15000)]
# Out:
#      symboling  normalized-losses    make  ... city-mpg highway-mpg  price
# 172          2              134.0  toyota  ...       24          30  17669
# 178          3              197.0  toyota  ...       20          24  16558
# 179          3              197.0  toyota  ...       19          24  15998
# 180         -1               90.0  toyota  ...       20          24  15690
# 181         -1              122.0  toyota  ...       19          24  15750
#
# [5 rows x 15 columns]

# %%
id1=cars[(cars["make"]=="toyota")&(cars["price"]>15000)].index
cars.drop(id1,inplace=True)

# %%
cars.shape
# Out:
# (200, 15)

# %%
cars[(cars["make"]=="isuzu")&(cars["price"]>20000)]
# Out:
#     symboling  normalized-losses   make  ... city-mpg highway-mpg  price
# 45          0              122.0  isuzu  ...       38          43  23000
#
# [1 rows x 15 columns]

# %%
cars.drop(45,inplace=True)

# %%
cars[(cars["make"]=="plymouth")&(cars["price"]>12000)]
# Out:
#      symboling  normalized-losses      make  ... city-mpg highway-mpg  price
# 124          3              122.0  plymouth  ...       19          24  12764
#
# [1 rows x 15 columns]

# %%
cars.drop(124,inplace=True)

# %%
plt.figure(figsize=(7,8))
sns.boxplot(data=cars,x="price",y="make")
plt.show()

# %%
cars[(cars["make"]=="mitsubishi")&(cars["price"]>12600)]
# Out:
#     symboling  normalized-losses        make  ... city-mpg highway-mpg  price
# 82          3              122.0  mitsubishi  ...       19          24  12629
# 83          3              122.0  mitsubishi  ...       19          24  14869
# 84          3              122.0  mitsubishi  ...       19          24  14489
#
# [3 rows x 15 columns]

# %%
id2=cars[(cars["make"]=="mitsubishi")&(cars["price"]>12600)].index
cars.drop(id2,inplace=True)

# %%
plt.figure(figsize=(7,8))
sns.boxplot(data=cars,x="price",y="make")
plt.show()
